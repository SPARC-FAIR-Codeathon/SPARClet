# %%
#Import libraries
from ipyleaflet import Map, VectorTileLayer, TileLayer

# %% [markdown]
# https://mapcore-demo.org/current/flatmap/v2/flatmap/83f6c97d571b67fb4c273e20287b53b4f0a1f70780d3d6a2a282e66cef5f9473/mvtiles/{z}/{x}/{y}

# %%
tile_urls= ['https://mapcore-demo.org/current/flatmap/v2/flatmap/83f6c97d571b67fb4c273e20287b53b4f0a1f70780d3d6a2a282e66cef5f9473/tiles/vagus_test_image/{z}/{x}/{y}',
           'https://mapcore-demo.org/current/flatmap/v2/flatmap/83f6c97d571b67fb4c273e20287b53b4f0a1f70780d3d6a2a282e66cef5f9473/mvtiles/{z}/{x}/{y}']

m = Map(
    basemap=TileLayer(
                    url=tile_urls[0], 
                    min_zoom=2),
    min_zoom=2,
    max_zoom=10,
    zoom=5,
    scroll_wheel_zoom=True,
    dragging=True,
    attribution_control=False,
    zoom_snap=False,
)


vl = VectorTileLayer(url=tile_urls[1])
m.add_layer(vl)
m
# Out:
# Map(center=[0.0, 0.0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
help(vl)
# Out:
# Help on VectorTileLayer in module ipyleaflet.leaflet object:
#
# class VectorTileLayer(Layer)
#  |  VectorTileLayer(*args: Any, **kwargs: Any) -> Any
#  |
#  |  VectorTileLayer class, with Layer as parent class.
#  |
#  |  Vector tile layer.
#  |
#  |
#  |  Attributes
#  |  ----------
#  |  url: string, default ""
#  |      Url to the vector tile service.
#  |  attribution: string, default ""
#  |      Vector tile service attribution.
#  |  vector_tile_layer_styles: dict, default {}
#  |      CSS Styles to apply to the vector data.
#  |
#  |  Method resolution order:
#  |      VectorTileLayer
#  |      Layer
#  |      ipywidgets.widgets.widget.Widget
#  |      ipywidgets.widgets.widget.LoggingHasTraits
#  |      traitlets.traitlets.HasTraits
#  |      traitlets.traitlets.HasDescriptors
#  |      InteractMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  redraw(self)
#  |      Force redrawing the tiles.
#  |
# ...
